# %%
#Понять то, что требует бизнесс от тебя и природу данных(насколько они точны и полны)
#Классифицируем проблемы, как управляемую и неуправляемую(в обучении), регрессивную или классификационную
#Скачать, очистить, потыкаться с данными и создать пару новых фич, что должны улучшить точность
#Создать тренировочный, тестируемый, валидационные сеты и подготовить дату для тренировка МЛ-ок
#Создать базовую модель, для того, чтобы сравнивать да тестить следующие модели
#Выбрать стратегию модели, трейнуть модель да потыкать гиперпараметры, чтобы наиболее отредачить модель
#"Экскрементировать" и скомбинировать результаты с нескольких стратегий, для лучших результатов
#Интерпретировать модель, изучить единичные предсказания, да представить свои находки


# business requirements -> probmlem identification -> data cleaning -> data preparation ->
# baseline models -> model training & evaluation -> regularization & ensembling ->
# interpretation & presentation

#business requirements или начальный сбор информации

"""
(Думаю, настало время для breast cancer db и loan определитель)

Не забывай, что тебе при изменениях где-то в дб следует документировать их в экселе, к примеру

(А так-же напутствие: "Бизнес кампаниям поебать на loss при расчетах
модели. Единственное они о чем беспокоятся - то, ради чего они тебя 
наняли. О том, что написано в ТЗ(чаще всего именно о деньгах)")

Тебе необходимо собрать как можно больше информации о проблеме, что тебе поставили

1. Какую проблему тебе задает бизнесс, что ты пытаешься решить при помощи MLO
2. В чем интерес кампании в решении этой проблемы? Что за impact будет иметь она на бизнессе
3. Как эта проблема решена сейчас, без инструментов машиного обучения
4. Кто будет использовать результаты этой модели и как это включено в дела кампании
5. Сколько данных у нас на руках, сколько было собрано?
6. Какие фичи(какие данные записывались) данные имеют? Имеется ли в данных параметр, что мы пытаемся вычислить?
7. Какие известные проблемы имеются с данными?(потери данных, ошибки при вводах, разные системы измерения...)
8. Можем ли мы взглянуть на семпл из датасета. Насколько семпл отражает весь датасет
9. Где дата хранится, как будет к ней получаться доступ
10...

При помощи этих вопросов тебе нужно вообще понять возможность исполнения этой штуки.
"""

# %%
#Problem identification

"""
1. Определяем то, является ли проект supervised learning или unsupervised learning
(Определяем, нужно ли нам постоянно вмешиваться в процесс обучения модели или она там сама сможет выделить кластера и все сделать.)
2. Тыкаемся с loss functions при исполнении и evaluation metrics
evaluation - для оптимизации моделей людьми
loss -  для оптимизации компьютерами

"""
# Out:
# '\n1. Определяем то, является ли проект supervised learning или unsupervised learning\n(Определяем, нужно ли нам постоянно вмешиваться в процесс обучения модели или она там сама сможет выделить кластера и все сделать.)\n2. Тыкаемся с loss functions при исполнении и evaluation metrics\nevaluation - для оптимизации моделей людьми\nloss -  для оптимизации компьютерами\n\n'

# %%
#Data cleaning

"""
1. Собственно. Закачка данных из различных источников. Сайтов, sql дб  т.д
2. Чтение(Просмотр на дупликаты так-же нужно проводить)(Ну и просмотр временных промежутков, на которых будет работать машина)
3. Просмотр данных(получение ренжов. Максимальных и минимальных значений, количество записей в бд и т.д.)
4. Выделение возможных зависимостей
8. Разведочный анализ данных и визуализация(Не забываем, что распространнение некоторых переменных может быть линейным, 
а может быть и экспоненциальным)
(просмотр данных пропадающих, неверных, просто слишком выбивающихся, детект аномалий)
9. Исследование зависимостей(Линейка не линейка, сбор данных о дата сете и проблеме)
5. Чистка нанов и засовывание категорических данных в колонки. Подумай над тем, как данные будешь обрабатывать и разработку фич)
6. Чистка от ненужных параметров(Иногда просто уникальных)
7. Чистка от параметров, что будут сбивать машину


"""
# Out:
# '\n1. Собственно. Закачка данных из различных источников. Сайтов, sql дб  т.д\n2. Чтение(Просмотр на дупликаты так-же нужно проводить)(Ну и просмотр временных промежутков, на которых будет работать машина)\n3. Просмотр данных(получение ренжов. Максимальных и минимальных значений, количество записей в бд и т.д.)\n4. Выделение возможных зависимостей\n8. Разведочный анализ данных и визуализация(Не забываем, что распространнение некоторых переменных может быть линейным, \nа может быть и экспоненциальным)\n(просмотр данных пропадающих, неверных, просто слишком выбивающихся, детект аномалий)\n9. Исследование зависимостей(Линейка не линейка, сбор данных о дата сете и проблеме)\n5. Чистка нанов и засовывание категорических данных в колонки. Подумай над тем, как данные будешь обрабатывать и разработку фич)\n6. Чистка от ненужных параметров(Иногда просто уникальных)\n7. Чистка от параметров, что будут сбивать машину\n8. Разведочный анализ данных\n9. Исследование зависимостей\n10. Планировка до
# ...

# %%
#Data preparation

"""
Помни, если категорий слишком много - модель самовыпилится и просто овер фитнится

Некоторые данные могут быть как категорными, так и нумерными, тебе решать что делать с ними

13. Разделение на сеты

10. Планировка добавления в данные новых фичур
11. Прикидываем какие колонки нужно совместить, какие изменить, какие
категорические колонки перебрать, какие склеить для простоты восприятия инфы машиной
какие данные следует выбрать из колонок, дабы улучшить восприятие машины
12. Какие зависимости были с данными в дб, с данными вне дб. Т.е. выбрать инфы из интернета, погоды к примеру
происходящего в мире(ибо к примеру, при расчёте цены билетов, следует понимать
что у нас были некоторые приколы в стране, по этому поводу)


Вменение пустых данных, Скалирование и Енкодирование(заполнение пустых номерных колонок)
1. Импутирование данных(заполнение пустот)
2.Скалирование данных(Перевод данных в 0,1 range)(перевод скалированных штук в отдельные колонки)
3. Вытягивает нумерные данные и колонки, дабы пересобрать приколы(дабы сделать X_train и т.д.)

"""
# Out:
# '\nПомни, если категорий слишком много - модель самовыпилится и просто овер фитнится\n\nНекоторые данные могут быть как категорными, так и нумерными, тебе решать что делать с ними\n\n13. Разделение на сеты\n\n10. Планировка добавления в данные новых фичур\n11. Прикидываем какие колонки нужно совместить, какие изменить, какие\nкатегорические колонки перебрать, какие склеить для простоты восприятия инфы машиной\nкакие данные следует выбрать из колонок, дабы улучшить восприятие машины\n12. Какие зависимости были с данными в дб, с данными вне дб. Т.е. выбрать инфы из интернета, погоды к примеру\nпроисходящего в мире(ибо к примеру, при расчёте цены билетов, следует понимать\nчто у нас были некоторые приколы в стране, по этому поводу)\n\n\nВменение пустых данных, Скалирование и Енкодирование(заполнение пустых номерных колонок)\n1. Импутирование данных(заполнение пустот)\n2.Скалирование данных(Перевод данных в 0,1 range)(перевод скалированных штук в отдельные колонки)\n3. Вытягивает нумерны
# ...

# %%
#Baseline models

"""
Создаем модели, что являются минимальным порогом эффективности
(Т.е. модели, которые в буквальном смысле всегда говорят ДА или НЕТ или просто хуярят рандомом)
(Или которая всегда возвращает mean таргетов)

Ну и сделай пару стратегий, что будут вычислять... К примеру средние продажи за месяц и тыкать их везде
Но когда магазин закрыт - функция всегда возвращает 0

Начинаем по классике - ЛинейнаяРегрессия

"""
# Out:
# '\nСоздаем модели, что являются минимальным порогом эффективности\n(Т.е. модели, которые в буквальном смысле всегда говорят ДА или НЕТ или просто хуярят рандомом)\n(Или которая всегда возвращает mean таргетов)\n\nНу и сделай пару стратегий, что будут вычислять... К примеру средние продажи за месяц и тыкать их везде\nНо когда магазин закрыт - функция всегда возвращает 0\n\n\n'

# %%
#Model Training & evaluation

"""
Начинаем проходить по всем моделям, дабы найти нормальную
Классификация. Регрессия, кластеринг, уменьшение измерения и т.д.
Начиная с самых простых моделей, заканчивая сложными
Найдя нормальную - тюним гиперпараметры(записывая результаты, 
дабы потом сверяться с более-менее эффективными штуками)

Сделать экселевский шит, после чего заполнить его всеми моделями, что ты попробовал и их результатами
А так-же всеми приколами и попытками, что ты сделал, для того, чтобы оптимизировать модель
(не забывай документировать потери при тренировке модели)
"""
# Out:
# '\nНачинаем проходить по всем моделям, дабы найти нормальную\nКлассификация. Регрессия, кластеринг, уменьшение измерения и т.д.\nНачиная с самых простых моделей, заканчивая сложными\nНайдя нормальную - тюним гиперпараметры(записывая результаты, \nдабы потом сверяться с более-менее эффективными штуками)\n\nСделать экселевский шит, после чего заполнить его всеми моделями, что ты попробовал и их результатами\nА так-же всеми приколами и попытками, что ты сделал, для того, чтобы оптимизировать модель\n(не забывай документировать потери при тренировке модели)\n'

# %%
#Regularization & Ensembling

"""
Берём лучшую модель и те, что выглядят неплохо и пытаемся их совместить
Когда настанет время - следует посмотреть на модели, почему она в некоторых моментах
делает неверные или плохие предсказания и посмотри, может сможешь заставить модель лучше работать
При необходимости стукнуть по моделям grid search-ем(определяем гипер параметры, что нам нужны и аплаем туда грид сеарч)
Ну и после - комбинировать разные типы моделей. Или на основе одной модели - трейнуть другую

k-fold cross validation

ensembling(тоже самое как и случаные леса, только вместо деревьев - модели)
Путем, чаще всего - выдачи среднего значения(ну и разным моделям можно выдать разный вес)
(Следует просто когда закончим с моделями - 5 самых лучших попросту ансаблюнуть
и уже от этого плясать)
stacking - тренировка модели на основе других моделей(те приколы с поколениями моделей)


"""
# Out:
# '\nБерём лучшую модель и те, что выглядят неплохо и пытаемся их совместить\nКогда настанет время - следует посмотреть на модели, почему она в некоторых моментах\nделает неверные или плохие предсказания и посмотри, может сможешь заставить модель лучше работать\nПри необходимости стукнуть по моделям grid search-ем(определяем гипер параметры, что нам нужны и аплаем туда грид сеарч)\nНу и после - комбинировать разные типы моделей. Или на основе одной модели - трейнуть другую\n\nk-fold cross validation\n\nensembling(тоже самое как и случаные леса, только вместо деревьев - модели)\nПутем, чаще всего - выдачи среднего значения(ну и разным моделям можно выдать разный вес)\n\nstacking - тренировка модели на основе других моделей(те приколы с поколениями моделей)\n\n\n'

# %%
#Interpretation & presentation

#// В принципе, как работа будет сделана - можно сделать сразу и через
#tkinter апишку, чтобы люди могли взаимодействовать с моделью.

"""

"Tkinter" - тут очень поможет.

После тренировки модели - пакуем её, да начинаем смачно напихивать все \
эти приколы штуками, что будут уже работать на обычную работу модели
Т.е. деплоим модель и строим взаимодействие между конечным пользователем
Определяем функции, что будут на определённые параметры определёнными образами
реагировать и т.д.
Ну и дать кампаниям инструменты для того, чтобы они могли потыкать модель
и посмотреть:"Имеет ли смысл полученный результат или модель завирается"


Начинаем все полученные веса перехуяривать в презентации.
Полученные результаты моделей - в презентации, да начинаем объяснять что на что
и как влияет, начинаем объяснять как что работатет и т.д.

Презентация 
Пойми о чем аудитория больше всего волнуется
Избегай кода и жаргона технического в презентации, запихай графиков
Сразу объясни почему те или иные штуки были выбраны, какие цифры показывают
другие модели, примерно сколько в числах потери денег у модели. Или у модели есть проблемы
с ложными положительными результатами, это так-же следует упомянуть
Фокус на метриках, что важны для бизнеса, именно те, что 
обычно используются в таких местах
Поговори о важных штуках для модели и как интерпретировать результат
Поговори о плюсах и ограничениях модели(Поговорить о слишком ложных показателях, указать, что тут как бы что-то идет
не по плану и чего не хватает или какая связь идет, из-за чего всё ломается)
Скажи о том, как можно усовершенствовать модель со временем. Или что делать
нужно. На какое время хватит модели, как часто её нужно ретренить. 
Как точное будет вычисление на дальнейшем ране, если не ретренить модель

На кегле соревнования есть. Туда можно пихать результаты модели, для того
чтобы попрактиковаться в машинном обучении в поле числовых данных
"""
