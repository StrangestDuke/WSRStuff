# %% [markdown]
# # Meow of the roow
# Who is the boss of this gym?

# %%
#Libraries import
import pandas as pd
import yaml
import json
import sys
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

#Datasets import
train_df = pd.read_csv('files to parse/Titanic/train.csv')
test_df = pd.read_csv('files to parse/Titanic/test.csv')

#Drop all categorical features(Чистим фрейм от даты, что не особо сильно будет 
#влиять на конечные данные)

cat_feat = ['PassengerId','Name', 'Sex','Ticket', 'Cabin', 'Embarked']
train_df.drop(cat_feat, axis = 1, inplace=True )

# %%
train_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_df.groupby(train_df['Age'].isnull()).mean()
# Out:
#        Survived    Pclass        Age     SibSp     Parch       Fare
# Age
# False  0.406162  2.236695  29.699118  0.512605  0.431373  34.694514
# True   0.293785  2.598870        NaN  0.564972  0.180791  22.158567

# %%
#Making a graph to show varivables and correlations
for i in ['Age', 'Fare']:
    died = list(train_df[train_df['Survived'] == 0][i].dropna())
    survived = list(train_df[train_df['Survived'] == 1][i].dropna())
    xmin = min(min(died), min(survived))
    xmax = max(max(died), max(survived))
    width = (xmax - xmin) / 40
    sns.histplot(died, color='r', kde=False, bins=np.arange(xmin, xmax, width))
    sns.histplot(survived, color='g', kde=False, bins=np.arange(xmin,xmax,width))
    plt.legend(['Did not survive', 'Survived'])
    plt.title('Overlaid histogram for {}'.format(i))
    plt.show()

# %%
for i,col in enumerate(['Pclass','family']):
    plt.figure(i)
    sns.catplot(x=col, y='Survived', data=train_df, kind='point', aspect=2,)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['family'] = train_df['SibSp'] + train_df['Parch']
sns.catplot(x='family', y='Survived', data=train_df, kind = 'point', aspect=2)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Family        0
# family        0
# dtype: int64

# %%
train_df['Age'].fillna(train_df['Age'].mean(), inplace=True)

# %%
train_df.drop(['SibSp','Parch'], axis = 1, inplace = True)
train_df.head()
# Out:
#    Survived  Pclass   Age     Fare  Family  family
# 0         0       3  22.0   7.2500       1       1
# 1         1       1  38.0  71.2833       1       1
# 2         1       3  26.0   7.9250       0       0
# 3         1       1  35.0  53.1000       1       1
# 4         0       3  35.0   8.0500       0       0
